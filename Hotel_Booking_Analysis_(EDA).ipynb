# %% [markdown]
# <a href="https://colab.research.google.com/github/gautamdhanrajnemmaniwar/Hotel_Booking_Analysis_EDA/blob/main/Hotel_Booking_Analysis_(EDA).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name** - Hotel Booking Analysis

# %% [markdown]
# ##### **Project Type** - Exploratory Data Analysis (EDA)
# ##### **Contribution** - Individual
# ##### **Project Member** - Gautam Dhanraj Anita Nemmaniwar

# %% [markdown]
# # **Project Summary**

# %% [markdown]
# **INTRODUCTION**
#
# * Hotels are an establishments that provide paid fooding and lodging generally for short duration of time. They often provide number of additional facilities such as restaurants, coffee shops, bars, swimming pool, banquet halls, etc.
#
# * As per '**Vision 2047: Indian Hotel Industry**' report by the **Hotel Association of India (HAI)**, the direct contribution of the hotel industry to **India's GDP** was **40 billion dollors** in **2022** and is expected to reach **68 billion dollors** by **2027**. The report also added that by **2047**, it will reach around **1 trillion dollors**.
#
# * As per report, **foreign tourist arrivals (FTAs)** in India are projected to increase from **1.5 million** in **2021** to **15 million** by **2024**, and touch **25 million** by **2030** and are further projected to grow attracting **100 million** tourists by **2047**.
#
# * Therefore, analyzing data related to hotel industry and providing sustainable insights is the need of the hour inorder to explore and achieve its utmost potential.

# %% [markdown]
# **SUMMARY**
#
# * The purpose of this project is to **explore the booking data set related to hotels** and identify any potential trends, relationships between key variables and provide necessary insights.
#
# * These data set contains **customer booking information**. And as part of analysis, various **statistical operations** are carried out and **visualizations** are created to see the correlation between various variables with the help of bar chart, pie chart, heat map, line plot, etc.
#
# * These project also contains detail explaination for every step taking during **data cleaning** and charts (like what is the use of this chart?, what are the insights?, etc) that are created.
#
# * And at last the project ends with brief and suffice conclusion that gives an overall understanding of the project.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/gautamdhanrajnemmaniwar/Hotel_Booking_Analysis_EDA

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **BUSINESS PROBLEM OVERVIEW**
#
# * Our primary goal is to conduct **EDA** on the provided dataset to discover important elements that govern the bookings and give insights to hotel management so that they can boost there business revenue and performance.
#
# **WORK FLOW**
#
# ![data-preparation-xenonstack.webp](data:image/webp;base64,...)

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# Exploring Hotel Booking dataset for buliding efficient business model.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries

import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import datetime as dt

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
# Mounting drive

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Reading file from the specific folder in 'CSV' format

df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Capstone Project/Module-2: Numerical Programming in Python/Capstone Project: Hotel Booking Analysis EDA/Hotel Bookings.csv")           # Reading the data file

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
# First 5 rows of the dataset

df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
# Last 5 rows of the dataset

df.tail()
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 119385             August                        35
# 119386             August                        35
# 119387             August                        35
# 119388             August                        35
# 119389             August                        35
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 119385                         30                        2
# 119386                         31                        2
# 119387                         31                        2
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count

print(df.shape)
print(f"Total number of Rows: {len(df)}")
print(f"Total number of Columns: {len(df.columns)}")
# Out:
# (119390, 32)
# Total number of Rows: 119390
# Total number of Columns: 32

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
# First hand info about dataset

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
# Columns names

df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count for Rows

print(f"Total number of duplicated Rows: {df.duplicated().sum()}")
# Out:
# Total number of duplicated Rows: 31994

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count

null_values = pd.DataFrame({'Null Values' : df.isnull().sum()})
null_values
# Out:
#                                 Null Values
# hotel                                     0
# is_canceled                               0
# lead_time                                 0
# arrival_date_year                         0
# arrival_date_month                        0
# arrival_date_week_number                  0
# arrival_date_day_of_month                 0
# stays_in_weekend_nights                   0
# stays_in_week_nights                      0
# adults                                    0
# children                                  4
# babies                                    0
# meal                                      0
# country                                 488
# market_segment                            0
# distribution_channel                      0
# is_repeated_guest                         0
# previous_cancellations                    0
# previous_bookings_not_canceled            0
# reserved_room_type                        0
# ...

# %%
# Null/Missing values in percentages (%)

null_values_percentage = pd.DataFrame({'Null Values in %' : df.isnull().sum()/len(df.index)*100})
null_values_percentage
# Out:
#                                 Null Values in %
# hotel                                   0.000000
# is_canceled                             0.000000
# lead_time                               0.000000
# arrival_date_year                       0.000000
# arrival_date_month                      0.000000
# arrival_date_week_number                0.000000
# arrival_date_day_of_month               0.000000
# stays_in_weekend_nights                 0.000000
# stays_in_week_nights                    0.000000
# adults                                  0.000000
# children                                0.003350
# babies                                  0.000000
# meal                                    0.000000
# country                                 0.408744
# market_segment                          0.000000
# distribution_channel                    0.000000
# is_repeated_guest                       0.000000
# previous_cancellations                  0.000000
# ...

# %%
# Visualizing the missing values using Heatmap

sns.heatmap(df.isnull(), cbar=False)
# Out:
# <Axes: >

# %% [markdown]
# From the above **Heat Map** what we can assume is that most of the null values are from columns '**company**' (**94%**) & '**agent**' (**14%**). And negligible from column '**country**' (**0.5%**).

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# * These data set contains over **119390** hotel bookings (**rows**) and **32** different variables (**columns**) such as 'hotel', 'is_canceled', 'lead_time', 'arrival_date_year', 'arrival_date_month', 'arrival_date_week_number', 'arrival_date_day_of_month', 'stays_in_weekend_nights', 'stays_in_week_nights', 'adults', 'children', 'babies', 'meal', 'country', 'market_segment', 'distribution_channel', 'is_repeated_guest', 'previous_cancellations', 'previous_bookings_not_canceled', 'reserved_room_type', 'assigned_room_type', 'booking_changes', 'deposit_type', 'agent', 'company', 'days_in_waiting_list', 'customer_type', 'adr', 'required_car_parking_spaces', 'total_of_special_requests', 'reservation_status', and 'reservation_status_date'.
#
# * Dataset variables are in **int64 -> 16 **, **float64 -> 4**, and **object -> 12** datatypes.
#
# * It also contains total of **31994 duplicate values** (rows).
# * Columns that have null/missing values are: **agent** -> 16340 (14%), **company** -> 112593 (94%), **country** -> 488 (0.4%), and **children** -> 4.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
# List of columns in the data frame

df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
# Dataset Describe
# Basic statistical analysis about the data frame

df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# 1. Hotel: H1= Resort Hotel, H2= City Hotel.
# 2. is_canceled: If the booking was cancelled(1) & not cancelled(0).
# 3. lead_time: Number of days that elapsed between booking and   arrival date.
# 4. arrival_date_year: Year of arrival date.
# 5. arrival_date_month: Month of arrival date.
# 6. arrival_date_week_number: Week number for arrival date.
# 7. arrival_day_of_month: Day of arrival date.
# 8. stays_in_weekend_nights: Booking on weekend night (saturday & sunday).
# 9. stays_in_week_nights: Booking on week nights (Monday to Friday).
# 10. adults: No. of adults.
# 11. children: No. of childrens.
# 12. babies: No. of babies.
# 13. meal: Kind of meal opted for.
# 14. country: Country code.
# 15. market_segment: Which segment the customers belong to.
# 16. distribution_channel: How did the customers accessed the stay (booking, direct, TA.TO).
# 17. is_repeated_guest: Guest coming for the first time or not.
# 18. previous_cancellation: Was their a cancellation before.
# 19. previous_booking_not_cancelled: Count of previous booking.
# 20. reserved_room_type: Type of room reserved.
# 21. assigned_room_type: Type of room assigned.
# 22. booking_changes: Count of changes made to booking.
# 23. deposit_type: Deposit type.
# 24. agent: Booked through agent.
# 25. days_in_waiting_list: Number of days in waiting list.
# 26. customer_type: Type of customer.
# 27. requried_car_parking: If car parking is requried.
# 28. total_of_special_req: No. of additional special requriements.
# 29. reservation_status: Reservation status.
# 30. reservation_status_date: Date of the specific status.
# 31. company
# 32. adr: Average Daily Rate

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check unique values for each variable (columns)

print("Number of uniques values for each column is:\n")
for i in df.columns.tolist():
  print(f"{i} ({df[i].nunique()}) : {df[i].unique()}\n")
# Out:
# Number of uniques values for each column is:
#
# hotel (2) : ['Resort Hotel' 'City Hotel']
#
# is_canceled (2) : [0 1]
#
# lead_time (479) : [342 737   7  13  14   0   9  85  75  23  35  68  18  37  12  72 127  78
#   48  60  77  99 118  95  96  69  45  40  15  36  43  70  16 107  47 113
#   90  50  93  76   3   1  10   5  17  51  71  63  62 101   2  81 368 364
#  324  79  21 109 102   4  98  92  26  73 115  86  52  29  30  33  32   8
#  100  44  80  97  64  39  34  27  82  94 110 111  84  66 104  28 258 112
#   65  67  55  88  54 292  83 105 280 394  24 103 366 249  22  91  11 108
#  106  31  87  41 304 117  59  53  58 116  42 321  38  56  49 317   6  57
#   19  25 315 123  46  89  61 312 299 130  74 298 119  20 286 136 129 124
#  327 131 460 140 114 139 122 137 126 120 128 135 150 143 151 132 125 157
#  147 138 156 164 346 159 160 161 333 381 149 154 297 163 314 155 323 340
#  356 142 328 144 336 248 302 175 344 382 146 170 166 338 167 310 148 165
# ...

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %% [markdown]
# ### Step-1: Making a copy of dataset

# %%
# Creating a copy of dataframe

hotel_df = df.copy()

# %% [markdown]
# ### Step-2: Removing duplicate rows

# %%
# Total number of rows before removing duplicates

hotel_df.shape
# Out:
# (119390, 32)

# %%
# Number of duplicate rows

hotel_df[hotel_df.duplicated()].shape
# Out:
# (31994, 32)

# %%
# Removing duplicate rows

hotel_df.drop_duplicates(inplace = True)

# %%
# Removing row adults, children and babies which on adding is equal to zero

hotel_df.drop(df[df['adults'] + hotel_df['babies'] + hotel_df['children'] == 0].index, inplace = True)

# %%
# Total number of rows after removing duplicate rows

hotel_df.shape
# Out:
# (87230, 32)

# %% [markdown]
# ### Step-3: Handling missing values

# %%
# Columns having missing values

hotel_df.isnull().sum()
# Out:
# hotel                                 0
# is_canceled                           0
# lead_time                             0
# arrival_date_year                     0
# arrival_date_month                    0
# arrival_date_week_number              0
# arrival_date_day_of_month             0
# stays_in_weekend_nights               0
# stays_in_week_nights                  0
# adults                                0
# children                              4
# babies                                0
# meal                                  0
# country                             447
# market_segment                        0
# distribution_channel                  0
# is_repeated_guest                     0
# previous_cancellations                0
# previous_bookings_not_canceled        0
# reserved_room_type                    0
# assigned_room_type                    0
# booking_changes                       0
# deposit_type                          0
# ...

# %%
# Replacing null values by 0 in columns 'company', 'agent', & 'children'

hotel_df[['company', 'agent', 'children']] = hotel_df[['company', 'agent', 'children']].fillna(0)

# %%
# Replacing the missing value for 'country' column

hotel_df['country'].fillna('others', inplace = True)

# %%
# Checking if all null values are removed from dataset

hotel_df.isnull().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# agent                             0
# company                           0
# days_in_waiting_list              0
# ...

# %% [markdown]
# ### Step-4: Removing outliers

# %%
# Build boxplots for various variables to remove outliers

columns = ['lead_time', 'stays_in_weekend_nights', 'stays_in_week_nights', 'adults', 'children', 'babies', 'required_car_parking_spaces', 'adr', 'previous_cancellations', 'previous_bookings_not_canceled', 'booking_changes']
n = 1
plt.figure(figsize=(20,15))

for column in columns:
  plt.subplot(4, 4, n)
  n = n + 1
  sns.boxplot(hotel_df[column])
  plt.tight_layout()

# %%
# Remove the outliers by using conditionals statements and update these values

hotel_df.loc[hotel_df.lead_time > 300, 'lead_time'] = 300
hotel_df.loc[hotel_df.stays_in_weekend_nights >=  5, 'stays_in_weekend_nights'] = 5
hotel_df.loc[hotel_df.adults > 4, 'adults'] = 4
hotel_df.loc[hotel_df.previous_bookings_not_canceled > 0, 'previous_bookings_not_canceled'] = 1
hotel_df.loc[hotel_df.previous_cancellations > 0, 'previous_cancellations'] = 1
hotel_df.loc[hotel_df.stays_in_week_nights > 10, 'stays_in_week_nights'] = 10
hotel_df.loc[hotel_df.booking_changes > 5, 'booking_changes'] = 5
hotel_df.loc[hotel_df.babies > 3, 'babies'] = 3
hotel_df.loc[hotel_df.required_car_parking_spaces > 1, 'required_car_parking_spaces'] = 1
hotel_df.loc[hotel_df.children > 4, 'children'] = 4
hotel_df.loc[hotel_df.adr > 300, 'adr'] = 300

# %%
# After removing outliers let's check once more with box plots

columns = ['lead_time', 'stays_in_weekend_nights', 'stays_in_week_nights', 'adults', 'children', 'babies', 'required_car_parking_spaces', 'adr', 'previous_cancellations', 'previous_bookings_not_canceled', 'booking_changes']
n = 1
plt.figure(figsize=(20,15))

for column in columns:
  plt.subplot(4, 4, n)
  n = n + 1
  sns.boxplot(hotel_df[column])
  plt.tight_layout()

# %% [markdown]
# ### Step-5: Changing datatypes

# %%
# Rewriting in proper Date-time format

hotel_df['reservation_status_date'] = pd.to_datetime(hotel_df['reservation_status_date'])

# %%
# Change datatype of variables children and agent to correct format from float64 to int64

hotel_df[['children','agent', 'company']] = hotel_df[['children','agent', 'company']].astype('int64')

# %% [markdown]
# ### Step-6: Adding new columns

# %%
# Combine columns 'stays_in_weekend' and 'stays_in _weekdays' into 'total_nights' column

hotel_df['total_nights'] = hotel_df.stays_in_weekend_nights + hotel_df.stays_in_week_nights

# %%
# Create a new column 'total_members' by adding columns 'kids' and 'adults'

hotel_df['total_members'] = hotel_df.adults + hotel_df.children + hotel_df.babies

# %%
# Creating 'reserved_room_assigned' variable which describe same room assigned or not

hotel_df['reserved_room_assigned'] = np.where(hotel_df['reserved_room_type'] == hotel_df['assigned_room_type'], 'yes', 'no')

# %%
# Creating 'guest_category' from variable 'total_people' to differentiate them in single, couple, and family

hotel_df['guest_category'] = np.where(hotel_df['total_members'] == 1, 'single', np.where(hotel_df['total_members'] == 2, 'couple', 'family'))

# %%
# Creating 'lead_time_category' from 'lead_time' variale to display category in low, medium, and high

hotel_df['lead_time_category'] = np.where(hotel_df['lead_time'] <= 30, 'low', np.where((hotel_df['lead_time'] > 30) & (hotel_df['lead_time'] < 90), 'medium', 'high'))

# %%
# Create a new column 'arrival_date' by merging columns 'arrival_date_day_of_month', 'arrival_date_month' & 'arrival_date_year'
# And change the 'arrival_date' column to date-time standard

hotel_df['arrival_date'] = hotel_df['arrival_date_day_of_month'].astype(str) + '-' + hotel_df['arrival_date_month'].astype(str) + '-' + hotel_df['arrival_date_year'].astype(str)
hotel_df['arrival_date'] = pd.to_datetime(hotel_df['arrival_date'], errors = 'coerce')

# %%
# Checking dataset after adding new columns

hotel_df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        300               2015               July
# 1  Resort Hotel            0        300               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  \
# 0                        0                     0       2  ...
# ...

# %% [markdown]
# ### Step-7: Changing datatype

# %%
# Coverting datatype of variable total_members to int64

hotel_df['total_members'] = hotel_df['total_members'].astype('int64')

# %%
# Checking if all manipulations are done right

hotel_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 87230 entries, 0 to 119389
# Data columns (total 38 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           87230 non-null  object
#  1   is_canceled                     87230 non-null  int64
#  2   lead_time                       87230 non-null  int64
#  3   arrival_date_year               87230 non-null  int64
#  4   arrival_date_month              87230 non-null  object
#  5   arrival_date_week_number        87230 non-null  int64
#  6   arrival_date_day_of_month       87230 non-null  int64
#  7   stays_in_weekend_nights         87230 non-null  int64
#  8   stays_in_week_nights            87230 non-null  int64
#  9   adults                          87230 non-null  int64
#  10  children                        87230 non-null  int64
#  11  babies                          87230 non-null  int64
# ...

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# 1. Made a copy of original dataset to a new one '**hotel_df**'.
#
# 2. Removed all duplicate rows.
#
# 3. Replaced all missing values by replacing null values with 0 and others in columns 'company', 'agent', & 'children' and 'country' respectively.
#
# 4. Removed outliers from columns 'lead_time', 'stays_in_weekend_nights', 'stays_in_week_nights', 'adults', 'children', 'babies', 'required_car_parking_spaces', 'adr', 'previous_cancellations', 'previous_bookings_not_canceled', and 'booking_changes'.
#
# 5. Changed datatypes of column 'reservation_status_date' to data-time and columns 'children','agent', & 'company' to integer type.
#
# 6. Added few new columns like 'total_nights', 'total_members', 'reserved_room_assigned', 'guest_category', 'lead_time_category', and 'arrival_date'.
#
# 7. Again converted column 'total_members' datatype to integer type.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# ### ***Univariate Analysis***

# %% [markdown]
# #### **Chart-1**: Which Top 10 countries have the highest bookings?

# %%
# Let's find top 10 countries with highest number of bookings

top_countries_with_highest_bookings = hotel_df.country.value_counts().reset_index().head(10)
top_countries_with_highest_bookings.columns = ['Country', 'No. of bookings']
print(f"Top 10 countries with highest bookings are:\n\n{top_countries_with_highest_bookings}")
# Out:
# Top 10 countries with highest bookings are:
#
#   Country  No. of bookings
# 0     PRT            27355
# 1     GBR            10424
# 2     FRA             8823
# 3     ESP             7244
# 4     DEU             5385
# 5     ITA             3061
# 6     IRL             3015
# 7     BEL             2081
# 8     BRA             1993
# 9     NLD             1910

# %% [markdown]
# Top 10 countries with highest bookings:
#
# **PRT** —> Portugal, **GBR** —> United Kingdom, **FRA** —> France, **ESP** —> Spain, **DEU** —> Germany, **ITA** —> Italy, **IRL** —> Ireland, **BEL** —> Belgium, **BRA** —> Brazil, **NLD** —> Netherlands.

# %%
# Lets visualize this information using bar chart

# Set the size of the figure
plt.figure(figsize = (10,5))

# Add title to the graph
plt.title('Top 10 countries with highest bookings', fontweight = "bold", size = 16)

# Plot the graph using seaborn bar graph
ax = sns.barplot(x = top_countries_with_highest_bookings['No. of bookings'], y = top_countries_with_highest_bookings.Country)

# Add title to the Y-axis
plt.ylabel("Countries")

# Simply assign the bar values to each bar and display the plot
ax.bar_label(ax.containers[0])

# Display plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * A **bar chart** is used when you want to show a **distribution of data** or perform comparison across different subgroups. From a bar chart, we can see which groups are highest, lowest or most common. In bar chart, the comparisons between different categories are easy and convenient to comprehend.
#
# * The reason behind using bar chart is to **compare different countries** with each country (**Y-axis**) displaying their **number of bookings** (**X-axis**) made respectively.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * From the above chart it appears a disproportionately high number of bookings from **Portugal** (PRT). The second country is the **United Kingdom** (GBR) which is approx. 60% behind to PRT.
#
# * And the least bookings as we can see is from **Netherlands** (NLD) and **Brazil** (BRA).

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Absolutely, comprehending such data can help organizations in finding new customers and focusing on existing ones through better services.
# > Let's see how such insights can help hotel business to improve their customer reach and prioritize there marketing:
#   * Helps in improvisation of **services and guest experience**.
#   * Helps in improving the effectiveness of **marketing** (like targeting audience using social media platforms).
#   * Helps in exploring **new customer base** to increase profits.
#   * Helps in creating better **strategies** to attract more guests.

# %% [markdown]
# #### **Chart-2**: Which Top 10 countries have most no. of guests?

# %%
# Let’s check country-wise guests for both the hotels

country_wise_guests = hotel_df[hotel_df['is_canceled'] == 0]['country'].value_counts().reset_index().head(10)
country_wise_guests.columns = ['Country', 'No. of guests']
country_wise_guests
# Out:
#   Country  No. of guests
# 0     PRT          17573
# 1     GBR           8440
# 2     FRA           7091
# 3     ESP           5382
# 4     DEU           4332
# 5     IRL           2347
# 6     ITA           1986
# 7     BEL           1670
# 8     NLD           1560
# 9     USA           1412

# %% [markdown]
# Top 10 countries with highest no. of guests:
#
# **PRT** —> Portugal, **GBR** —> United Kingdom, **FRA** —> France, **ESP** —> Spain, **DEU** —> Germany, **ITA** —> Italy, **IRL** —> Ireland, **BEL** —> Belgium, **USA** —> America, **NLD** —> Netherlands.

# %%
# Lets visualize this information using bar chart

# Set the size of the chart
plt.figure(figsize = (10,5))

# Add title to the chart
plt.title('Top 10 countries with total no. of guests', fontweight = "bold", size = 16)

# Plot the chart using seaborn bar chart
ax = sns.barplot(x = country_wise_guests.Country, y = country_wise_guests['No. of guests'])

# Simply assign the bar values to each bar and display the data
ax.bar_label(ax.containers[0])

# Display plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * Bar charts show a **comparison of different values** in sub-categories in rectangular format. They also help us compare numerical values like integers and percentages.
#
# * Here bar chart is used to **compare different countries** (**X-axis**) along with **total number of guest** (**Y-axis**) for indiviual country.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Similar to the previous data, the above chart appears to have huge number of guests from **Portugal** (PRT) followed by **United Kingdom** (GBR) and **France** (FRA) which is approx. 50% less in numbers compared to PRT.
#
# * There is a slight change in the data as seen in the previous one. **Brazil** is nowhere to be found in this graph and **America** (USA) has taken 10th place in the number of guests with **Netherlands** (NLD) on 9th place.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Definitely, such data will not only help in expanding the business but also helps in **strengthening customer-organization relationship**.
#
# > Let's discover how such findings can help businesses to increase there revenue/profits:
#   * Developing a perfect match between **personalization** (like food & interior design) **and guest experience**.
#   * Building and taking **data-driven strategies and decisions**.
#   * Helps in **staff optimization** (like appointing foreign language speaking employees).

# %% [markdown]
# #### **Chart-3**: Which Top 10 agents have most no. of bookings?

# %%
# Let's see top 10 agents that make most bookings using their ID's

agent_wise_bookings = pd.DataFrame(hotel_df['agent'].value_counts(normalize = True)).reset_index().head(10)
agent_wise_bookings.columns = ['Agent', 'No. of bookings in %']
agent_wise_bookings.drop(agent_wise_bookings[agent_wise_bookings['Agent'] == 0].index, inplace=True)
agent_wise_bookings['No. of bookings in %'] = round(100 * agent_wise_bookings['No. of bookings in %'], 2)
agent_wise_bookings
# Out:
#    Agent  No. of bookings in %
# 0      9                 32.93
# 1    240                 14.94
# 3     14                  3.83
# 4      7                  3.78
# 5    250                  3.19
# 6    241                  1.88
# 7     28                  1.71
# 8      8                  1.59
# 9      1                  1.41

# %%
# Let's visualize this information using bar chart

# Set the size of the chart
plt.figure(figsize = (10,5))

# Plot the chart using seaborn bar plot
ax = sns.barplot(x = agent_wise_bookings['Agent'], y = agent_wise_bookings['No. of bookings in %'], order = agent_wise_bookings.sort_values('No. of bookings in %', ascending = False).Agent)

# Simply assign the bar values to each bar and display the plot
ax.bar_label(ax.containers[0])

# Add title to the chart
plt.title('Top 10 agents with most bookings in %', fontweight = "bold", size = 16)

# Display plot
plt.show()

# %% [markdown]
# Here, '9' - **agent no. - 9**, similarly '240' - **agent no. 240**, '7' means **agent no. - 7**, and so on for all the agents.

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * **Bar charts** are used for showing **segments of information**. Bar charts are one of the many techniques used to present data in a visual form so that the reader may recognize patterns or trends easily and understand them more effectively.
#
# * In this case, bar chart is used to compare **ID's of agents** shown on **X-axis** with values as **total no. of bookings** on **Y-axis**.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * From the above chart, **Agent no. 9** has made most no. of bookings, following this **Agent no. 240** takes the second spot with half the bookings of Agent no. 9.
#
# * And the least bookings are done by **Agent no. 8** and **Agent no. 1** respectively.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, such data can guide us in **acknowledging the customers/guests perference of booking**. And it can also help hotels to work with such mediators/middle agents to make stronger end-to-end channels for betterment of their businesses.
#
# > Let's explore more on how these insights can aid in favour of hotels to increase there bookings and better their outreach:
#   * Assist in evaluating the **business market and competition**.
#   * Can help in maximizing revenue through **price recommendations**.
#   * Aid in **promoting the brand** more efficiently through there own networks.

# %% [markdown]
# #### **Chart-4**: Which type of hotel (resort hotel and city hotel) has more bookings?

# %%
# Let's see the percentage of resort hotel bookings compared to city hotel bookings

total_bookings = len(hotel_df['hotel'])

# Total percent count for resot hotel
resort_hotel_booking = round(len(hotel_df[hotel_df['hotel'] == 'Resort Hotel']) / total_bookings * 100)
print(f"Resort hotel booking % is: {resort_hotel_booking}%.")

# Total percent count for city hotel
city_hotel_booking = round(len(hotel_df[hotel_df['hotel'] == 'City Hotel']) / total_bookings *  100)
print(f"\nCity hotel booking % is: {city_hotel_booking}%.")
# Out:
# Resort hotel booking % is: 39%.
#
# City hotel booking % is: 61%.

# %%
# Let's visualize this information using pie chart

# Plot the chart with pie chart
plt.pie([resort_hotel_booking, city_hotel_booking], labels = ['Resort Hotel Bookings', 'City Hotel Bookings'], autopct = '%1.1f%%', explode = (0, 0.1), textprops = {'fontsize': 14})

# Add title to the chart
plt.title('Total no. of bookings per hotel in %', fontweight = "bold", size = 16)

# Display plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * A **pie chart** is **divided into a few slices**. Where each individual slice represents a percentage of the whole. It works well when one wants to create, present and understand simple data.
#
# * In above scenario we used pie chart to **compare resort hotel bookings with city hotel bookings** in percentage inorder to get a grasp of which type of hotel is more popular.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * We can conclude that the majority of bookings are from **City hotel**. City hotel are more popular than Resort hotel.
#
# * **Resort hotel** account for **39%** of bookings, where as **City hotel** account for **61%** of bookings.
#
# * Reason for such disparity might be that City hotels are **cheaper** as compared to Resort hotels. And City hotels are **convenient to travel and stay** as they are in middle of the city where as Resort hotels are many times far from city and close to aesthetic locations.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positively, such unique data will help hotel brands to build and develop there hotels on the lines of **customer's affordability, availability and accessibility**.
# > Let's find out how such data can help hotel brands to make more profits:
# * Easy to manage the **supply chain** (like edibles and furniture goods for specific occasions.)
#   * For example, Resort hotels can see more hike in their businesses on weekends or long holiday stays.
# * Benefits of proper **hotel location** can aid in high visibility, high occupancy and high productivity.
#   * To give an example, most of the bigger hotel brands like 'JW Marriott' or 'Hyatt' are located in middle of the city.
# * **High risk v/s High returns**: reachability, better services, efficient staff, etc; can help hotel brands to attract more visitors that will help full in the brand making.

# %% [markdown]
# #### **Chart-5**: What are different modes of booking? and Which is the most preferable mode of booking by customers?

# %%
# Let's see different modes of booking along with their total booking value in %

modes_of_booking = hotel_df.market_segment.value_counts(normalize = True).reset_index()
modes_of_booking.columns = ['Booking_Mode', 'No. of bookings in %']
modes_of_booking['No. of bookings in %'] = round(100 * modes_of_booking['No. of bookings in %'], 2)
modes_of_booking
# Out:
#     Booking_Mode  No. of bookings in %
# 0      Online TA                 59.10
# 1  Offline TA/TO                 15.88
# 2         Direct                 13.50
# 3         Groups                  5.64
# 4      Corporate                  4.81
# 5  Complementary                  0.79
# 6       Aviation                  0.26
# 7      Undefined                  0.00

# %%
# Let's visualize this data using horizontal bar graph

# Figure Size
fig, ax = plt.subplots(figsize = (10, 5))

# Horizontal Bar Plot
ax.barh(modes_of_booking.Booking_Mode, modes_of_booking['No. of bookings in %'])

# Add x, y gridlines
ax.grid(color ='green', linestyle ='-', linewidth = 0.5, alpha = 0.2)

# Show top values
ax.invert_yaxis()

# Add annotation to bars
for i in ax.patches:
    plt.text(i.get_width()+0.2, i.get_y()+0.5, str(round((i.get_width()), 2)), fontsize = 10, fontweight = 'bold', color = 'black')

# Add Plot Title
ax.set_title('Different modes of booking hotels with values in %', fontweight = "bold", size = 16)

# Show Plot
plt.show()

# %% [markdown]
# > market_segment:
# * **Direct** -> direct booking from hotel website or front desk,
# * **Corporate** -> like wholesaler booking,
# * **Online TA** -> Online Travel Agents,
# * **Offline TA/TO** -> offline Travel agents or travel operators,
# * **Complementary** -> given in discounts or as part of promotions,
# * **Group** -> group booking, and
# * **Aviation** -> bookings done by airports.

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * **Horizontal bar graphs** are graphical representations of data using bars that run horizontally along the X-axis. They are unique & attractive to **visualize**, simple to **comprehend** and easy to **design**.
#
# * In above framework we are using horizontal bar chart that depicts **X-axis** as total **no. of bookings** done by each mode along with **Y-axis** as actual **booking mode** respectively.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Highest bookings around **59%** are done by **Online Travel Agents** (Online TA).
#
# * Further, almost **16%** of bookings are made via **Offline Travel Agents** (Offline TA/TO), followed by **13.5%** through **Direct** bookings without the help of any other agents.
#
# * Least bookings are done by **Aviation** with around **2%** of total booking share.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Certainly, because traditionally, hotel reservation was not an easy task for the hotel's staff and customers too. But with new channels/sources, it simplifies the booking process and reduces the chances of errors.
#
# > Let's decrypt how such insights can help customers to book a room through multiple sources with ease and convenience:
#   * Through **online mode**, hotels are always available for bookings and generate an instant confirmation receipts if available.
#     * Like 'JW Marriott' & 'Hyatt' have their own **Hotel Reservation System** through their web portals.
#   * **Round the clock bookings** where anyone can book a stay any time of the day or night.
#   * With the help of **multiple booking modes**, hotels can focus more on improving guest experience and reduce the work for front desk.
#     * For instance using **Web**('Yatra' & 'MakeMyTrip'), using **third party agents** ('kesari tours' & 'Veena world'), etc.

# %% [markdown]
# #### **Chart-6**: What are the total no. of bookings done year-wise & month-wise?

# %%
# Let's find out year-wise & month-wise values in %

# For Year
year_wise = pd.DataFrame(hotel_df['arrival_date'].dt.strftime('%Y').value_counts(normalize = True).head().reset_index())
year_wise.columns = ['Year', 'Total Count in %']
year_wise['Total Count in %'] = round(100 * year_wise['Total Count in %'], 2)
year_wise_sorted = year_wise.sort_values(by = ['Year'])

print(f"Year-wise Table\n{year_wise_sorted}")

# For Months
month_wise = pd.DataFrame(hotel_df['arrival_date'].dt.strftime('%m').value_counts(normalize = True).reset_index())
month_wise.columns = ['Month', 'Total Count in %']
month_wise['Total Count in %'] = round(100 * month_wise['Total Count in %'], 2)
month_wise_sorted = month_wise.sort_values(by = ['Month'])
print(f"\nMonth-wise Table\n{month_wise_sorted}")
# Out:
# Year-wise Table
#    Year  Total Count in %
# 2  2015             15.23
# 0  2016             48.51
# 1  2017             36.26
#
# Month-wise Table
#    Month  Total Count in %
# 11    01              5.37
# 8     02              6.97
# 5     03              8.59
# 3     04              9.06
# 2     05              9.57
# 4     06              8.89
# 1     07             11.51
# 0     08             12.89
# 7     09              7.66
# 6     10              7.93
# 10    11              5.70
# 9     12              5.86

# %%
# Let's visualize year-wise data using Bar graph

# Set the background style of the plot
sns.set_style('darkgrid')

# Plot the graph using the seaborn bar plot
ax = sns.barplot(x ='Year', y ='Total Count in %', data = year_wise_sorted, palette ='plasma')

# Add title to the graph
plt.title('Year-wise highest no. of bookings in %', fontweight = "bold", size = 16)

# Simply assign the bar values to each bar and display the plot
ax.bar_label(ax.containers[0])

# Display plot
plt.show()

# %%
# Let's visualize month-wise data using Bar graph

# Create a figure with a specific size
plt.figure(figsize=(10, 5))

# Set the background style of the plot
sns.set_style('ticks')

# Plot the graph using the default estimator mean
ax = sns.barplot(x ='Month', y ='Total Count in %', data = month_wise_sorted, palette ='plasma')

# Add title to the graph
plt.title('Month-wise highest no. of bookings in %', fontweight = "bold", size = 16)

# Simply assign the bar values to each bar and display the plot
ax.bar_label(ax.containers[0])

# Diaplay plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * A **bar chart/graph** represents **categorical data with rectangular bars** with heights proportional to the values assigned. They can be plotted vertically or horizontally. The advantages of using bar graph is that they are easy to understand, simpler to visualize, and not so difficult to create.
#
# * Here we have designed two charts/graphs in one section itself.
#   * In first one, the bar chart displays **X-axis** as **years** and **Y-axis** as **total booking counts** per year.
#   * In second one similarly we have presented **X-axis** as **months** (like 01=Jan, 05=May, 12=Dec, etc.) and **Y-axis** as **total booking counts** per month.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Insights for **Year-wise data** (2015, 2016 & 2017):
#   * As of total bookings, **48.5%** bookings belong to **2016** which is the highest among all, whereas **36%** bookings are from year **2017** and remaining **15%** are from **2015**.
#   * Here we can see that their is an increasing tendency in bookings year wise. But simultaneously their a fall in bookings in year 2017 as compared to 2016.
#
# * Insights for **Month-wise data** (January - December):
#   * As mentioned above, **August** & **July** are the most occupied months with **13%** & **11.5%** respectively.
#   * While **January**, **November** & **December** are least occupied months with **5 - 6%** each.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Indeed, such data can support hotels in identifying & exploring booking patterns, optimizing their room rates, checking their inventories, improving customer experiences and organizing their staffs.
#
# > Let's dive into details to check how proper use of data can create positive business impact:
#   * **Identifying booking trends** can aid in understanding which month is the busiest, which will ultimately lead to strategizing and organizing their work.
#   * With the help of **effective marketing**, hotels can offer coupons and discounts for those months which are least occupied.
#   * Inhand data can assist hotels in **enhancing scalability** & **manage pricing**.

# %% [markdown]
# #### **Chart-7**: What are different types of meal? and Which meal is ordered most?

# %%
# Let's find out different types of meal and their total count in %

hotel_meals = pd.DataFrame(hotel_df['meal'].value_counts(normalize = True).reset_index())
hotel_meals.columns = ['Meal_Type', 'Total_Count in %']
hotel_meals.drop(3, inplace = True)
hotel_meals['Total_Count in %'] = round(100 * hotel_meals['Total_Count in %'], 2)
print(f"Types of meal offered along with their respective counts\n\n{hotel_meals}")
# Out:
# Types of meal offered along with their respective counts
#
#   Meal_Type  Total_Count in %
# 0        BB             77.85
# 1        SC             10.77
# 2        HB             10.41
# 4        FB              0.41

# %%
# Let's picturize above content using Bar graphical

# Create a figure with a specific size
plt.figure(figsize=(10, 5))

# Use seaborn to create a barplot
ax = sns.barplot(x = 'Meal_Type', y = 'Total_Count in %', data = hotel_meals)

# Add title to the graph
plt.title('Different types of meal with total count in %', fontweight = "bold", size = 16)

# Simply assign the bar values to each bar and display the plot
ax.bar_label(ax.containers[0])

# Show the plot
plt.show()

# %% [markdown]
# Types of Meal:
# * **BB** -> Bed & Breakfast
# * **SC** -> Self-Catering (no meal package)
# * **HB** -> Half-Board (breakfast and one other meal — like lunch or dinner)
# * **FB** -> Full-Board (breakfast, lunch and dinner)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * A **bar chart** is generally used when there is a need to display a **distribution of data points or carry out a comparison of values** across different subgroups of the data set. The main variable of the bar chart is the category variable. Some examples include: industry type, race, sex, age group, etc.
#
# * In above framework we are using bar chart that indicates **X-axis** as **different types of meal** offered by hotels and **Y-axis** indicates **total count** of meals ordered by customers for each sub-category meal.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Out of all meals, **BB** (Bed & Breakfast) is the most ordered meal which is around **78%**, followed by **HB** (Half Board) with **10.5%**, **SC** (no meal package) with **11%**, and **FB** (Full Board) is just **0.5%**.
#
# * Reason behind **BB** being most ordered meal is that many hotels provide **complimentary breakfast** to their customers before heading out. And at the same time even customers ensure that they don't go out empty Stomach as it might be difficult for them to find local restaurants or food in the morning.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Obviously, because providing a room with meals is a practice that is considered standard across the hotel industry. Due to food delivery apps and diverse cuisine restaurants, hotel's food and beverage is slowly dying out in favor of other options.
#
# > Let's discover how hotels can improve their food service to adapt with guest satisfaction will the help of data analysis:
#   * Easy-to-order **menu**,
#   * Delivering on **time**,
#   * Providing maximum **comfort while dining**,
#   * Being consistent in **service & quality**,
#   * Giving **complimentary breakfast**,
#   * Offering a **wide variety of food & drinking items**,
#   * **Partnering with local restaurants** to specialize menu,
#   * Keeping **menu fresh & updated**,
#   * Having various **feedback channels** to improve services, and
#   * Lastly **monitoring staff performances**.

# %% [markdown]
# #### **Chart-8**: What are different types of customer? and Which type of customer are often found in hotels?

# %%
# Let's find out different types of customers and percentage value

hotel_customers = hotel_df.customer_type.value_counts(normalize = True).reset_index()
hotel_customers.columns = ['Customer_Type', 'Total_Count']
hotel_customers['Total_Count'] = round(100 * hotel_customers['Total_Count'], 2)
print(f"Types of customer visiting along with their total count in %.\n\n{hotel_customers}")
# Out:
# Types of customer visiting along with their total count in %.
#
#      Customer_Type  Total_Count
# 0        Transient        82.38
# 1  Transient-Party        13.40
# 2         Contract         3.59
# 3            Group         0.62

# %%
# Let's visualize this data using horizontal bar graph.

# Figure Size
fig, ax = plt.subplots(figsize =(10, 5))

# Horizontal Bar Plot
ax.barh(hotel_customers.Customer_Type, hotel_customers.Total_Count)

# Remove axes splines
for s in ['left', 'right']:
    ax.spines[s].set_visible(False)

# Remove x, y Ticks
ax.xaxis.set_ticks_position('none')
ax.yaxis.set_ticks_position('none')

# Add x, y gridlines
ax.grid(color ='grey', linestyle ='-', linewidth = 0.5, alpha = 0.2)

# Show top values
ax.invert_yaxis()

# Add annotation to bars
for i in ax.patches:
    plt.text(i.get_width()+0.2, i.get_y()+0.5, str(round((i.get_width()), 2)), fontsize = 10, fontweight ='bold', color ='green')

# Add label to the axis
ax.set(xlabel = "Total Count in %", ylabel = "Customer Type")

# Add title to the plot
plt.title(label = 'Types of customer seen in hotels with total count in %', fontweight = "bold", size = 16)

# Show Plot
plt.show()

# %% [markdown]
# Type of Customer:
# * **Contract** —> when the booking has a contract associated to it;
# * **Group** —> when the booking is associated to a group;
# * **Transient** —> when the booking is not part of a group or contract, and is associated to a customer who stays for a temporary period of time;
# * **Transient-party** —> when the booking is transient, but is associated to at least other transient booking.

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * A horizontal bar graph displays the information using horizontal bars. It helps us to **visualize and compare data for different categories** more skillfully. They are mostly used to display nominal variables like modes of operation or different departments in an organization.
#
# * A horizontal bar graph is displayed using rectangular bars of lengths proportional to the values that they represent.
#   * On the **Y-axis** of the graph, it shows data for **different types of customer** in hotels that are being compared.
#   * The **X-axis** represents the **values** corresponding to each of these sub-category.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Above graph shows that, nearly **82%** of customers belong to **Transient** type which is highest among all the sub-categories.
#
# * Then comes **Transient-Party** type of customer that occupy almost **13%** of the total customer base.
#
# * Lastly, we have **Contract** & **Group** type of customer that hold approx. **3.5%** and **0.6%** respectively which is the least among all.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, such information/representation can help hotel industry in analyzing customer inquiries, complaints and reviews. These can also aid in understanding guest preferences and expectations.
#
# > Let's explore how such insights can help hotel industry to provide their customers the best experience and comfort:
#   * **Improving customer experience** inorder to uncover customer preferences & behavior.
#     * Knowing your clients can help hotels in creating a better experience and exploring new trends.
#   * **Targeted marketing** lets businesses analyze booking history, preferences, demographics and brand promotion.
#     * With the help of these insights hotels can recommend relevant products, services and give offers to customers.
#   * **Marriott Hotels** is such one amazing example that uses hotel data analysis to drive revenue growth and enhance customer loyalty.
#     * With the help of **dynamic pricing strategy** based on trends, company has achieved a 5% increase in revenue per room.

# %% [markdown]
# #### **Chart-9**: How many confirmed bookings are there per month? and What is the total count for cancelled bookings?

# %%
# Let's find out total confirmed bookings per month from January to December

confirmed_bookings = hotel_df[hotel_df.is_canceled =='0']
confirmed_bookings['arrival_date_month'] = hotel_df['arrival_date'].dt.month
final_booking_count = confirmed_bookings['arrival_date_month'].value_counts().sort_index().reset_index()
final_booking_count.columns = ['Month', 'Total_Booking_Count']
final_booking_count
# Out:
#     Month  Total_Booking_Count
# 0       1                 4685
# 1       2                 6083
# 2       3                 7489
# 3       4                 7900
# 4       5                 8344
# 5       6                 7756
# 6       7                10043
# 7       8                11242
# 8       9                 6682
# 9      10                 6921
# 10     11                 4973
# 11     12                 5112

# %%
# Similarly let's check for the cancelled bookings in percentage(%)

print("Total Bookings cancelled\n")
cancelled_bookings = hotel_df.is_canceled.value_counts().reset_index()
cancelled_bookings.columns = ['is_canceled', 'Total_Count']
print(cancelled_bookings)

print("\n\nCancelation percentage\n")
cancelled_bookings_percentage = hotel_df.is_canceled.value_counts(normalize=True).reset_index()
cancelled_bookings_percentage.columns = ['is_canceled', 'Total_Count in %']
cancelled_bookings_percentage['Total_Count in %'] = round(100 * cancelled_bookings_percentage['Total_Count in %'], 2)
print(cancelled_bookings_percentage)
# Out:
# Total Bookings cancelled
#
#    is_canceled  Total_Count
# 0            0        63221
# 1            1        24009
#
#
# Cancelation percentage
#
#    is_canceled  Total_Count in %
# 0            0             72.48
# 1            1             27.52

# %%
# Let's visualize this data using horizontal bar graph
# First let's see for confirmed bookings per month

# Figure Size
fig, ax = plt.subplots(figsize = (10, 5))

# Horizontal Bar Plot
ax.barh(final_booking_count.Month, final_booking_count.Total_Booking_Count, color = "brown")

# Remove axes splines
for s in ['left', 'right']:
    ax.spines[s].set_visible(False)

# Add x, y gridlines
ax.grid(color = 'grey', linestyle = '--', linewidth = 0.5, alpha = 0.2)

# Show top values
ax.invert_yaxis()

#Add annotation to bars
for i in ax.patches:
    plt.text(i.get_width()+0.2, i.get_y()+0.5, str(round((i.get_width()), 2)), fontsize = 10, fontweight ='bold', color ='black')

# Add label to the axis
ax.set(xlabel = "Total Bookings", ylabel = "Months")

# Add title to the plot
plt.title(label = 'Total confirmed bookings per month', fontweight = "bold", size = 16)

# Show Plot
plt.show()

# %%
# Let's visualize this information using pie chart
# Now let's check for the cancelled bookings with its percentage(%)

# Declaring exploding pie
explode = [0, 0.1]

# Define Seaborn color palette to use
palette_color = sns.color_palette('pastel')

# Plotting data on chart
plt.pie(cancelled_bookings_percentage['Total_Count in %'], labels = ['0 - Not Canceled', '1 - Canceled'], colors = palette_color, explode = explode, autopct = '%.0f%%')

# Displaying the title
plt.title("Bookings Cancelled / Not Cancelled", fontweight = "bold", size = 16)

# Displaying chart
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Here we have used two types of chart for two different problem statements.
#
# * **Total confirmed bookings per month** (Horizontal Bar Chart):
#   * **Bar charts** highlight differences between categorical data. They are used to comprehend relationships between categorical variables. For example, gender is a categorical variable (male & female).
#
#   * In first case we have used **horizontal bar graph** whose **Y-axis** represents data for different **months** in numercial terms (1-12 : January-December) and **X-axis** represents the **total confirmed bookings** for each respective months.
#
# * **Cancelled bookings in percentage(%)** (Pie Chart):
#   * **Pie chart** is like a big pie that represent the whole data, which is divided into many parts or slices, where each part of the pie represents a sub-category (in %) of the whole data. For example, survey of movies or electoral candidates.
#
#   * In second case we have used pie chart to compare the confirmation of bookings for hotels, where '**0**' - stands for '**Not Canceled**' and '**1**' - stands for '**Canceled**'.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Insights for 1st chart - **Total confirmed bookings per month** (January - December):
#
#   * Refering to above graph, **August** & **July** has most confirmed bookings.
#   * While **January**, **November** & **December** are considered to be the least booking months.
#   * Confirmed bookings see a rise for each month starting from January (4685) to their highest in August (11242). And then again see a fall upto December (5112).
#
# * Insights for 2nd chart - **Cancelled bookings in percentage(%)** (0' -> 'Not Canceled' and '1' -> 'Canceled'):
#   * **Canceled** ('**1**') bookings account for **28%** of total bookings, where as **Not Canceled** account for **72%**. Therefore most of the bookings are part of confirmed bookings.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Definitely, cancellation rates for hotel industry is gradually increasing and that can be painful for overall business. For this reason, such awareness in hand with the help of data can help the indutry to find more effective ways to combat on-time cancellations.
#
# Let's see how hotels can overcome cancellation rates with the help of such insights:
#   * **Taking** **Booking Deposits** while booking a room in advance to avoid cancellations.
#   * **Personalization** (calling your guests directly) is one of the best ways to avoid cancellations without even taking booking deposit.
#   * **Increasing cancellation time** can benefit hotels and give customers more time to decide for cancellation.
#   * **Being Responsive and Proactive** by keeping track of cancellations and immediately getting in touch if guests don't show.

# %% [markdown]
# #### **Chart-10**: What are different types of deposit? and Which deposit type is most popular in hospitality industry?

# %%
# Let's explore different deposit types along with their total count in %

deposit_type = hotel_df['deposit_type'].value_counts(normalize = True).reset_index()
deposit_type.columns = ['Deposit_Type', 'Total_Count in %']
deposit_type['Total_Count in %'] = round(100 * deposit_type['Total_Count in %'], 2)
deposit_type
# Out:
#   Deposit_Type  Total_Count in %
# 0   No Deposit             98.69
# 1   Non Refund              1.19
# 2   Refundable              0.12

# %%
# Lets portray these data with the help of bar chart

# Set the size of the chart
plt.figure(figsize = (10,5))

# Plot the data with bar chart using seaborn
ax = sns.barplot(x = deposit_type['Deposit_Type'], y = deposit_type['Total_Count in %'], palette = 'deep')

# Add title to the graph
plt.title('Types of deposit with total count in %', fontweight = "bold", size = 16)

# Simply assign the bar values to each bar and display the plot
ax.bar_label(ax.containers[0])

# Display plot
plt.show()

# %% [markdown]
# Deposit types:
#
# * **No Deposit** —> no deposit was made.
# * **Non Refund** —> a deposit that was made will not be given back in case of cancellation or you don't turn up.
# * **Refundable** —> a deposit that was made will be given back even in case of cancellation.

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * A **Bar Chart** uses rectangular bars to convey data. The longer the bar, the greater the value. If one axis (say X-axis) shows the categories then other axis (say Y-axis) shows the values. Bar charts are good for showing how data change over time. They can help in estimating key values at a glance.
#
# * As shown above in bar chart, we have assigned **X-axis** with three different types of **deposits** and **Y-axis** with their **total count** in percentage(%).

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * As we can see from above chart that most of the hotels have '**No Deposit Policy**'. Here '**No Deposit**' type holds almost **98.5%** of the total value of deposit category.
#   * Even customers prefer those hotels that have '**No Deposit Policy**'. And the burden of loss is incurred by hotels if customers don't turn up or cancel their bookings.
# * Next sub-category is '**Non Refund**' type of deposit which is **1%** of the total count.
#   * Non-Refund policy is mostly seen in chained-brand hotels.
#
# * Lastly, we have '**Refundable**' type of deposit which is next to negligible accounting for **0.1%**.

# %% [markdown]
# #### **Chart-11**: How many customers opt for car parking space?

# %%
# Let's see the percentage of customers selecting a hotel based on car parking space

car_parking_space_percentage = hotel_df.required_car_parking_spaces.value_counts(normalize=True).reset_index()
car_parking_space_percentage.columns = ['Car_Parking (Yes-0 / No-1)', 'Total_Count in %']
car_parking_space_percentage['Total_Count in %'] = 100 * car_parking_space_percentage['Total_Count in %']
car_parking_space_percentage
# Out:
#    Car_Parking (Yes-0 / No-1)  Total_Count in %
# 0                           0         91.624441
# 1                           1          8.375559

# %%
# Lets visualize this information using pie chart

# Declaring exploding pie
explode = [0.1, 0]

# Plotting data on chart
plt.pie(car_parking_space_percentage['Total_Count in %'], labels = ['Yes - car parking', 'No - car parking'], colors = sns.color_palette('deep'), explode = explode, autopct='%.0f%%')

# Add title to the chart
plt.title('Number of customers opting for car parking space in %', fontweight = "bold", size = 16)

# Displaying chart
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * A **Pie Chart** (or circle graph) is a type of chart that uses a circular chart to view data. In this, the **size of each slice of the pie is equal to the size of the group as a whole**. They are commonly used in business and educational related presentations to display proportion of different categories such as expenditures, population groups, subjects, etc.
#
# * In this scenario we have used pie chart to compare the values between parking options (**0** -> '**Yes**' & **1** -> '**No**') in case of customers.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Based on above representation, **majority of customers perfer those hotels that have sufficient car parking space**.
#
# * Customers that want car parking space account for **92%** (0 - '**Yes**'), where as customers that don't check for car parking space account for just **8%** (1 - '**No**') of total.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * Positively, since having an **accessible and safe parking space** is one of the most important thing that a customer expects when booking a room. And most of the hotels are unable to provide sufficient parking space for their guests.
#
# * Therefore, such insights can aid hotels in realizing the need for parking space (especially for ubran areas as it is more crowded) and work on solving hotel parking issues with the help of **effective hotel parking management systems and technologies**.

# %% [markdown]
# #### Few extra questions along with there graph & brief insight

# %% [markdown]
# ##### Q.1) ***Reserved Room Type***

# %%
# Let's find out what type of room is mostly reserved by customers in percentage(%)

room_reserved = hotel_df.reserved_room_type.value_counts(normalize=True).reset_index()
room_reserved.columns = ['Room_Type', 'Total_Reservation_Count in %']
room_reserved['Total_Reservation_Count in %'] = round(100 * room_reserved['Total_Reservation_Count in %'], 2)
room_reserved
# Out:
#   Room_Type  Total_Reservation_Count in %
# 0         A                         64.70
# 1         D                         19.92
# 2         E                          6.92
# 3         F                          3.23
# 4         G                          2.35
# 5         B                          1.14
# 6         C                          1.05
# 7         H                          0.68
# 8         L                          0.01

# %%
# Let's see this data with the help of bar graph

# Set the size of the chart
plt.figure(figsize = (14,5))

# Use sns barplot to plot bar plot
ax = sns.barplot(x = 'Room_Type', y = 'Total_Reservation_Count in %', data = room_reserved, errwidth = 0, palette = 'dark')

# Simply assign the bar values to each bar
ax.bar_label(ax.containers[0])

# Add title to the chart
plt.title('Types of Room Reserved by the customers in %', fontweight = "bold", size = 16)

# Display plot
plt.show()

# %% [markdown]
# ######  What is/are the insight(s) found from the chart?

# %% [markdown]
# * The most reserved room type booked by customers is '**A**' that accounts for nearly **65%** of the total reservation.
#
# * Followed by '**D**' -> **20%**, '**E**' -> **7%**, '**F**' -> **3%** and '**G**' -> **2%** type of room respectively.
#
# * The remaining types of room i.e. '**B**', '**C**', '**H**' & '**L**' occupy **3%** of the total reservation

# %% [markdown]
# ##### Q.2)  ***Assigned Room Type***

# %%
# Let's identify different types of room that are assigned by hotels to customers and there total count in percentage(%)

room_assigned = hotel_df.assigned_room_type.value_counts(normalize=True).reset_index()
room_assigned.columns = ['Room_Type', 'Total_Assigned_Count in %']
room_assigned['Total_Assigned_Count in %'] = round(100 * room_assigned['Total_Assigned_Count in %'], 2)
room_assigned
# Out:
#    Room_Type  Total_Assigned_Count in %
# 0          A                      53.06
# 1          D                      25.70
# 2          E                       8.24
# 3          F                       4.16
# 4          G                       2.86
# 5          C                       2.48
# 6          B                       2.08
# 7          H                       0.81
# 8          I                       0.40
# 9          K                       0.21
# 10         L                       0.00

# %%
# Let's see this data with the help of bar graph

# Set the size of the chart
plt.figure(figsize = (14,5))

# Use sns barplot to plot bar plot
ax = sns.barplot(x = 'Room_Type', y = 'Total_Assigned_Count in %', data = room_assigned, errwidth = 0, palette = 'colorblind')

# Simply assign the bar values to each bar
ax.bar_label(ax.containers[0])

# Add title to the chart
plt.title('Types of Room Assigned to the customers in %', fontweight = "bold", size = 16)

# Display plot
plt.show()

# %% [markdown]
# ###### What is/are the insight(s) found from the chart?

# %% [markdown]
#  Sometimes the assigned room type may differ from the reserved room type due to hotel operation reasons (like overbooking, maintenance, etc) or by customer request itself.
#
#  * '**A**' is the most assigned room type for customers by hotels that stands for approx. **53%** of the total assigned quota.
#   * Also from the previous chart we can say that, mostly customers booking for a specific room will be alloted the same room by hotels during their check-in.
#
# * Then comes '**D**', '**E**' and '**F**' type of assigned room with **25%**, **8%** and **4%** of share respectively.

# %% [markdown]
# ##### Q.3) ***Repeated Guest*** (0 - 'No' & 1 - 'Yes')

# %%
# Let's see if there were any repeated guest or not from the previous booking list

repeated_guest = hotel_df.is_repeated_guest.value_counts(normalize=True).reset_index()
repeated_guest.columns = ['Guest (1->Yes/ 0->No)', 'Guest_Percentage']
repeated_guest['Guest_Percentage'] = round(100 * repeated_guest['Guest_Percentage'], 2)
repeated_guest
# Out:
#    Guest (1->Yes/ 0->No)  Guest_Percentage
# 0                      0             96.14
# 1                      1              3.86

# %%
# Let's see this data using Pie Chart

# Declaring exploding pie
explode = [0, 0.1]

# Define Seaborn color palette to use
palette_color = sns.color_palette('colorblind')

# Plotting data on chart
plt.pie(repeated_guest['Guest_Percentage'], labels = ['0 - Guest Not Repeated', '1 - Guest Repeated'], colors = palette_color, explode = explode, autopct = '%.0f%%')

# Add title to the chart
plt.title('Total No. of Guest Repeated in %', fontweight = "bold", size = 16)

# Displaying chart
plt.show()

# %% [markdown]
# ###### What is/are the insight(s) found from the chart?

# %% [markdown]
# * From above data we can conclude that, **most of the guests are one-time visitors** and only few loyal customers or customers who like the service of the hotel choose to visit again.
#
# * **96%** guest are from '**Not Repeated**' category and only **4%** belong to '**Repeated**' category.

# %% [markdown]
# ##### Q.4) ***Total Members per Room***

# %%
# Let's see how many guests are present per reservation in percentage(%)

guests_per_reservation = hotel_df.total_members.value_counts(normalize=True).reset_index()
guests_per_reservation.columns = ['Guests', 'Total_Count in %']
guests_per_reservation['Total_Count in %'] = round(100 * guests_per_reservation['Total_Count in %'], 2)
guests_per_reservation
# Out:
#    Guests  Total_Count in %
# 0       2             65.41
# 1       1             18.42
# 2       3             11.55
# 3       4              4.46
# 4       5              0.15
# 5       6              0.00

# %%
# Let's visualize this data using bar chart

# Set the size of the chart
plt.figure(figsize = (10,5))

# Use sns barplot to plot bar plot
ax = sns.barplot(x = 'Guests', y = 'Total_Count in %', data = guests_per_reservation, errwidth = 0, palette = 'muted')

# Simply assign the bar values to each bar
ax.bar_label(ax.containers[0])

# Add title to the chart
plt.title('Total No. of Guests per Reservation in %', fontweight = "bold", size = 16)

# Displaying plot
plt.show()

# %% [markdown]
# **1** -> One Guest
#
# **2** -> Two Guests
#
# **3** -> Three Guests
#
# **4** -> Four Guests
#
# **5** -> Five Guests

# %% [markdown]
# ###### What is/are the insight(s) found from the chart?

# %% [markdown]
# Here what we can see is that **every reservation has atleast 1 member as a guest** and most of the times rooms have 2 guests.
#
# * Top 3 insights:
#   * **2** member reservation -> **65%**
#   * **1** member reservation -> **18%**
#   * **3** member reservation -> **12%**

# %% [markdown]
# ##### Q.5) ***Reservation Status Type***

# %%
# Let's find out what are different types of reservation status along with their values in %

reservation_status = hotel_df.reservation_status.value_counts(normalize=True).reset_index()
reservation_status.columns = ['Reservation_Status_Type', 'Total_Count in %']
reservation_status['Total_Count in %'] = round(100 * reservation_status['Total_Count in %'], 2)
reservation_status
# Out:
#   Reservation_Status_Type  Total_Count in %
# 0               Check-Out             72.48
# 1                Canceled             26.36
# 2                 No-Show              1.16

# %%
# Let's display this information with the help of bar graph

# Set the size of the chart
plt.figure(figsize = (10,6))

# Use sns barplot to plot bar plot
ax = sns.barplot(x = 'Reservation_Status_Type', y = 'Total_Count in %', data = reservation_status, errwidth = 0, palette = 'bright')

# Simply assign the bar values to each bar by passing containers method to bar_label function and display the plot
ax.bar_label(ax.containers[0])

# Add title to the chart
plt.title('Different Types of Reservation Status with there Total Count in %', fontweight = "bold", size = 16)

# Display plot
plt.show()

# %% [markdown]
# Three categories of reservation status are:
# * **Canceled** —> Booking was canceled by the customer.
# * **Check-Out** —> Customer has checked-in and also checked-out.
# * **No-Show** —> Customer did not check-in.

# %% [markdown]
# ###### What is/are the insight(s) found from the chart?

# %% [markdown]
# * Here we can see that **most of the customers have visited** the hotel. The percentage count for '**Check-out**' type of reservation status is **72%** which is substantially more compared to other types.
#
# * Second most visible category of reservation status is '**Canceled**' type that accounts for **26%**. And very negligible amount of guest don't turn up once they have done the reservation i.e., **No-Show** - **1.1%**.
#
# * Most of the time the burden falls on hoteliers when customers cancel there booking if there are no pre-booking or depoist or reservation charges in place.

# %% [markdown]
# ### ***Bivariate Analysis***

# %% [markdown]
# #### **Chart-1**: What is the cancelation rate for each type of hotel?

# %%
# Let's directly visualize the data using Bar chart

# Adjust figure size
plt.figure(figsize=(10, 5))

# Plotting count plot
ax = sns.countplot(x = 'hotel', hue = "is_canceled", data = hotel_df, palette = 'bright')

# Set axes and title label
plt.xlabel('Hotel')
plt.ylabel('Total cancelation count')
plt.title("Cancelation rates in City hotel and Resort hotel", fontweight = "bold", size = 16)

# Set the percent(%) value on each bar
total = float(len(hotel_df)/100)
for p in ax.patches:
    height = p.get_height()
    if np.isnan(height):
        height=0
    ax.text(p.get_x()+p.get_width()/2., height, '{:1.2f}%'.format(height/total), ha="center")

# Set Y-axis label
ax.set_ylabel('Cancellation / No-Cancellation Count in %')

# Remove y-axis ticklabels
plt.yticks([])

# Display plot
plt.show()

# %% [markdown]
# **0** -> 'No Cancelation'
#
# **1** -> 'Cancelation'

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * A **count plot** is a specific way of representing data using rectangular bars where the length of each bar is proportional to the value it represents. In real life, count plots are commonly used to represent business data.
#
# * As represented above we are using bar chart that exhibits **X-axis** as different **types of hotel** (City & Resort) and **Y-axis** exhibits **total count** of cancelation and no cancelation for each hotel.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * **Most bookings are in City hotel**.
#
# * **Cancelation** (1) in Resort hotel is less compared to City hotel.
#
# * **No Cancelation** (0) is more in City hotel compared to Resort hotel.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * Certainly such information inhand can aid hotels overcome cancellation rates that are steadily rising for years, due to the culture of '**book now, pay later**' scheme created by **online travel agents** (OTAs) giants.
#
# * Let's co-relate how we can combat the number of cancellations with the help of above data:
#   * Establishing a **strong email strategy** that will give guests the opportunity to cancel and help hotels to organize their availability.
#
#   * Making sure that hotels have a **Solid Cancellation Policy** in place.
#
#   * Offering discounts and better deals over **direct booking**.
#     * As per a study done in 2019 in US, cancellations from a hotel's website amount to only 19% as compared to 39% on Booking.com and 25% on Expedia.

# %% [markdown]
# #### **Chart-2**: What is the Average Daily Rate (ADR) for each hotel (Resort & City) (Month-wise & Year-wise)?

# %%
# Let's directly visualize the given facts on Average Daily Rate (ADR) for month-wise using lineplot

# Setting the size of the figure
plt.figure(figsize=(14,6))

# Setting the theme for chart
sns.set_theme(style = "darkgrid")

# Plotting facts on chart with seaborn
sns.lineplot(x = 'arrival_date_month', y = 'adr', hue = 'hotel', data = hotel_df).set(xlabel = "Month", ylabel = "Average Daily Rate (ADR)")

# Set title
plt.title('Average Daily Rate (ADR) for each hotel (Resort & City) month-wise', fontweight = "bold", size = 16)

# Change the title of legend
plt.legend(title = 'Hotel')

# Displaying chart
plt.show()

# %%
# Let's directly visualize the given facts on Average Daily Rate (ADR) for month-wise using lineplot

# Setting the size of the figure
plt.figure(figsize=(10,5))

# Setting the theme for chart
sns.set_theme(style = "darkgrid")

# Plotting facts on chart with seaborn
sns.lineplot(x = 'arrival_date_year', y = 'adr', hue = 'hotel', data = hotel_df).set(xlabel = "Year", ylabel = "Average Daily Rate (ADR)")

# Set title
plt.title('Average Daily Rate (ADR) for each hotel (Resort & City) year-wise', fontweight = "bold", size = 16)

# Change the title of legend
plt.legend(title = 'Hotel')

# Displaying chart
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * **A line plot is a series of data points connected by straight line**. They are often used to visualise a pattern in data overtime periods or time series.
#
# * Some of the **benefits of using line plot** are:
#   * It helps to show small shifts in large set of data.
#   * It helps show trends for different periods (months, days, years).
#   * They are easy to understand.
#   * Inorder to compare data, more than one line can be plotted in same chart.
#
# * Here we have used two lineplots for two different time-periods (Month & Year):
#   * In case of **month-wise** plot, different **months** (January - December) are shown on **X-axis** and change in **Average Daily Rate** (**ADR**) is shown on **Y-axis**.
#
#   * In case of **year-wise** plot, different **years** (2015, 2016 & 2017) are shown on **X-axis** and change in **Average Daily Rate** (**ADR**) is shown on **Y-axis**.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Insights for ***Month-wise*** plot:
# * **Resort Hotel**:
#   * The average daily rate (**ADR**) is more during months **June**, **July**, **August** and **September**.
#   * The **ADR** is less during **November**, **January**, **February** and **March**.
#
# * **City Hotel**:
#   * The average daily rate (**ADR**) is more during months **May**, **June**, **July** and **August**.
#   * The **ADR** is less during **November**, **December**, **January**, **February** and **March**.
#
# Insights for ***Year-wise*** plot:
# * **Resort Hotel**:
#   * **ADR** is highest in year **2017** and lowest in year **2016**.
#   * Here ADR starting from year 2015 then falls to new low in 2016 and then rises humongously in year 2017.
# * City Hotel:
#   * **ADR** is highest in year **2017** and lowest in year **2015**.
#   * In these case ADR has a stip and continous rise in all three years (2015, 2016 & 2017).
#
# * In general, **ADR is more for city hotel as compared to resort hotel**. That means guest-wise, city hotel receives more guest than resort hotel.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * For sure because **Average Daily Rate** (ADR) plays a great role for increasing a hotel's revenue.
#   * Why is it important? The answer to that question is that, to run a hotel successfully and to get proper return on investment (**ROI**), hotel business requries a **hike in hotel ADR** inorder to overcome various hotel requirements like high operational & managerial cost, inventory maintenance and other expenses to manage a hotel.
#
# * **ADR** is a key performance indicator that is used to calculate the average price or rate for each room sold for a particular day. It is the most popular method used in hotels to measure their performance and stay competitive.
#
# * Let's see how data analysis can assist hotels to build prompt strategies to increase their ADR:
#   * By keeping **watch on competitors** and their pricing.
#   * Having **optimum and feasible pricing**
#     * It is important to analyze the current market, customer demand, guest's capacity to pay the price before setting any price.
#
#   * Offering better **packages & deals** and high-value **promotions** with discounts.
#
#   * Prioritizing the hotel **distribution channel** by analyzing which OTAs (Online Travel Agents) are getting maximum bookings.

# %% [markdown]
# #### **Chart-3**: Is high lead_time responsible for booking cancellations? and Is reserved room not assigned a reason for booking cancellations?

# %%
# Let's visualize first plot by using two variables lead_time_category & is_canceled to check the impact of lead time on reservation status

# Set the size of the figure
plt.figure(figsize = (10,5))

# Plotting count plot
ax = sns.countplot(x = hotel_df['lead_time_category'], hue = hotel_df['is_canceled'], palette = 'dark')

# Set axes and title label
plt.xlabel('Lead Time Categories')
plt.ylabel('Booking Count')
plt.title('Booking cancellation based on Lead Time', fontweight = "bold", size = 16)

# Set the percent(%) value on each bar
total = float(len(hotel_df)/100)
for p in ax.patches:
    height = p.get_height()
    if np.isnan(height):
        height=0
    ax.text(p.get_x()+p.get_width()/2., height, '{:1.2f}%'.format(height/total), ha="center")

# Set Y-axis label
ax.set_ylabel('Cancellation / No-Cancellation Count in %')

# Remove y-axis ticklabels
plt.yticks([])

# Display plot
plt.show()

# %% [markdown]
# > '**lead_time_category**':
# * **low** -> lead time with less than 30 days,
# * **medium** -> lead time in between 30 - 90 days, and
# * **high** -> lead time with more than 90 days.
#
# > '**is_canceled**':
# * **0** -> Not Cancelled
# * **1** -> Cancelled

# %%
# Let's visualize second plot by using two variables reserved_room_assigned & is_canceled to check the booking cancellation

# Set the size of the figure
plt.figure(figsize=(10,5))

# Plotting the count plot
ax = sns.countplot(x = hotel_df['is_canceled'], hue = hotel_df['reserved_room_assigned'], palette = 'muted')

# Set axes and title label
plt.xlabel('Cancellation Status')
plt.ylabel('Reserved Room Assigned Count')
plt.title('Booking cancellation based on Reserved Room Assigned or not', fontweight = "bold", size = 16)

# Set the percent(%) value on each bar
total = float(len(hotel_df)/100)
for p in ax.patches:
    height = p.get_height()
    if np.isnan(height):
        height=0
    ax.text(p.get_x()+p.get_width()/2., height, '{:1.2f}%'.format(height/total), ha="center")


# Display plot
plt.show()

# %% [markdown]
# > '**is_canceled**':
# * **0** -> Not Cancelled
# * **1** -> Cancelled

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * A **countplot** is a type of bar plot that shows the counts of observations using bars. A countplot can be used to visualize the distribution of a single categorical variable or to compare the distribution of multiple categorical variables. They can allow individual to quickly understand how many different categories exist within the dataset.
#
# * Here we have designed two plots using countplot to check various reasons for booking cancellations:
#   * In first case, on **X-axis** we have represented **lead time category** and on **Y-axis** we have shown **booking count** (canceled / not canceled). And '**is_canceled**' variable is used to plot the difference.
#
#   * In second case, on **X-axis** we have represented **cancellation status** (yes / no)  and on **Y-axis** we have shown **Reserved Room Assigned or not count**. And '**reserved_room_assigned**' variable is used to plot the difference.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Countplot-1: '***lead_time_category v/s is_canceled***':
#
#   * In case of **low lead time**, booking cancellations are few.
#   * Guests who book rooms with more than 30 days in advance are more likely to cancel their bookings (**medium & high lead time**).
#   * Overall in any case, **lead time is not the major reason for cancelling a booking**.
#
# * Countplot-2: '***reserved_room_assigned v/s is_canceled***':
#   * Mostly **customers are alloted the same room as per reservation** made by them. And in case if customers are not alloted the same room type then they prefer to have different room of same standards.
#
#   * In any case, not able to assign the reserved room to guest is not the reason for cancelling a booking because **less than 1% of guest went for cancellation** when they were not assigned the same reserved room.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * Customer behaviour has changed alot since the pandemic. The way in which people make reservations has also changed alot due to booking platforms and channels. These days guests can make a last-minute reservation which can make it much harder to predict consumer behaviour.
#
# * Therefore, with the help of right insights, hotels can **identify patterns**, **anticipate high & low demands** and **learn about target marketing**. They can also work on there **pricing and marketing strategies** in order to sell more rooms to more guests at the right price and right time.
#
# * Moreover, nowadays **customers are not worried about the more or less lead time or what type of room they are assigned** unless the services provided by the hotels are top notch and prices are affordable and reasonable.

# %% [markdown]
# #### **Chart-4**: Which guest category (single, couple & family) has how many reservations?

# %%
# Let's plot the guest category data for each hotel type with countplot

# Set the size of the figure
plt.figure(figsize = (10,5))

# Plotting Countplot
ax = sns.countplot(x = hotel_df['hotel'], hue = hotel_df['guest_category'], palette = 'tab20')

# Set the percent(%) value on each bar
total = float(len(hotel_df)/100)
for p in ax.patches:
    height = p.get_height()
    if np.isnan(height):
        height=0
    ax.text(p.get_x()+p.get_width()/2., height, '{:1.2f}%'.format(height/total), ha="center")

# Set the title of plot
ax.set_title('Each guest category reservation in %', fontweight = "bold", size = 16)

# Set Y-axis label
ax.set_ylabel('Count in %')

# Remove y-axis ticklabels
plt.yticks([])

# Display plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * A **countplot** is used to show the counts (occurrences) of the observations for the categorical variable. It uses the concept of a bar chart for the visual depiction. One can easily understand the results in countplot by comparing the values of different variables in a single depiction.
#
# * The above chart shows the **comparision between different hotels occupying different types of guest**. Here we have used two variables for comparision from the original dataset i.e., '**hotel**' & '**guest_category**' and displayed the values in percentage(%).

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * **City hotel** has the most no. of guest from all guest categories.
# * Most visible guest category in hotels is of **couples**.
# * When it comes of **family** booking most customers prefer city hotel over resort hotel.
# * A city hotel is preferred when booking for a **single** person.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positively, because for any hotel the success of the business depends on the satisfaction of the guests. That's why it's necessary to gather and use data that can help hotels to make decisions that will improve their experience and increase sales.
#
# > Let's see how information in hand can help in creating positive guest experience and boost hotel profits:
#   * **Personalised marketing** by using techniques like messaging/emailing and offerings guest their specific needs and preferences like complimentary room upgrades, spa or massage services, free breakfast, etc.
#   * **Optimised pricing strategies** can help hotels in strategically pricing hotel's rooms and services that can help hotels stay competitive in the market as well as generate more profits.
#     * By optimising hotel pricing strategies based on guest related data, hotels can ensure that they are maximising revenue while also providing guests with a fair price.
#   * **Proper inventory management** can help hotels maintain amenities that are most in demand and optimise accordingly.
#     * For example, if guests request a certain type of room or amenity for many times, then hotels can adjust their inventory to meet that demand.

# %% [markdown]
# #### **Chart-5**: Which distribution channels and market segments has the most no. of cancellations?

# %%
# Let's plot a countplot for distribution channels along with the no. of booking cancellations

# Set the size of the figure
plt.figure(figsize = (10,5))

# Ploting Countplot
ax = sns.countplot(x = hotel_df['distribution_channel'], hue = hotel_df['is_canceled'], palette = 'pastel')

# Set the percent(%) value on each bar
total = float(len(hotel_df)/100)
for p in ax.patches:
    height = p.get_height()
    if np.isnan(height):
        height=0
    ax.text(p.get_x()+p.get_width()/2., height, '{:1.2f}%'.format(height/total), ha="center")

# Set the title label
ax.set_title('Booking cancellations for each distribution channel in %', fontweight = "bold", size = 16)

# Set Y-axis label
ax.set_ylabel('Cancellation / No-Cancellation Count in %')

# Remove y-axis ticklabels
plt.yticks([])

# Display the plot
plt.show()

# %% [markdown]
# > **distribution_channel**:
#   * **Direct** -> direct booking from hotel website or front desk,
#   * **Corporate** -> like wholesaler booking,
#   * **TA/TO** -> Travel Agents / Tour Operators, and
#   * **GDS** -> Global Distribution Systems.
#
# > **is_canceled**:
#   * **0** -> Not Canceled
#   * **1** -> Canceled

# %%
# Let's plot a countplot for market segments along with the no. of booking cancellations

# Set the size of the figure
plt.figure(figsize = (15,5))

# Plotting Countplot
ax = sns.countplot(x = hotel_df['market_segment'], hue = hotel_df['is_canceled'])

# Set the title of graph
ax.set_title('Booking cancellations for each market segment in %', fontweight = "bold", size = 16)

# Set the percent(%) value on each bar
total = float(len(hotel_df)/100)
for p in ax.patches:
    height = p.get_height()
    if np.isnan(height):
        height=0
    ax.text(p.get_x()+p.get_width()/2., height, '{:1.2f}%'.format(height/total), ha="center")

# Set Y-axis label
ax.set_ylabel('Cancellation / No-Cancellation Count in %')

# Remove y-axis ticklabels
plt.yticks([])

# Display plot
plt.show()

# %% [markdown]
# > **market_segment**:
#   * **Direct** -> direct booking from hotel website or front desk,
#   * **Corporate** -> like wholesaler booking,
#   * **Online TA** -> Online Travel Agents,
#   * **Offline TA/TO** -> offline Travel agents or travel operators,
#   * **Complementary** -> given in discounts or as part of promotions,
#   * **Group** -> group booking, and
#   * **Aviation** -> bookings done by airports.
#
# > **is_canceled**:
#   * **0** -> Not Canceled
#   * **1** -> Canceled

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * A **countplot** can be thought of as a **histogram of a categorical variable**. The basic application is similar to that of barplot, where one can compare counts/values across categorical variables. With the help of countplot one can easily identify which category has how many counts/values.
#
# * Here we have designed two types of plot inorder to check **booking cancellations** across **distribution channel** and **market segment** in percentage(%) respectively.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * ***Booking cancellations through distribution channels***:
#   * '**TA/TO**' has the most booking cancellation share as well as most confirmed booking share too among all.
#
#   * Bookings made through **'Direct'**, **'Corporate'**, and **'GDS'** distribution channels are very unlikely to be canceled.
#
# * ***Booking cancellations through market segment***:
#   * Most of the cancellations belong to '**Online TA**' & '**Offline TA/TO**' market segment.
#
#   * Remaining '**Direct**', '**Corporate**' & '**Groups**' market segments have minimal cancellation rate.
#
# * From above what we can conculde is that **most of the customers prefer online travel agents or operators** for either reservation or cancellation.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Definitely. But why so?
# * In these highly competitive hotel industry, **effective distribution channel & market segment management plays a key role** in driving bookings & maximizing revenue.
#
# * Understanding the various hotel distribution channels & market segments and how to leverage them is essential for hotels to stay ahead in the **digital era**. These channels can be online or offline and enable hotels to **reach a wide audience**, **expand their market reach**, and **generate more bookings**.
#
# >  Let's unfold how such insights can help hotels to sell their rooms to potential guests with the help of these distribution channels and market segments:
#   * **Enhancing visibility** through various channels such as online travel agencies (OTAs), global distribution systems (GDS), direct booking platforms, etc; can aid hotels to expand their reach to a wide range of potential guests.
#     * Increased visibility leads to greater brand awareness, attracting more guests and generating higher occupancy rates.
#   * **Improving guest experience** by providing seamless and user-friendly interfaces, making it easier for guests to find suitable accommodations, exploring amenities, providing guest reviews and ratings for informed decisions and making advance reservations.
#   * **Expanding market reach** through partnerships with OTAs and GDS platforms, hotels can tap into a vast network of travel agents and agencies.
#     * By diversifying distribution channels and exploring various market segements, hotels can reach new markets and unlock untapped revenue streams.

# %% [markdown]
# ### ***Multivariate Analysis***

# %% [markdown]
# #### **Chart-1**: Correlation Heatmap

# %%
# Correlation Heatmap visualization code

# Set the size of the plot
plt.subplots(figsize = (25,8))

# Plotting correlation heatmap with seaborn
ax = sns.heatmap(hotel_df.corr(), cmap = "YlGnBu", annot = True)

# Set the title of plot
ax.set_title('Correlation Heatmap for Hotel Booking Dataset', fontweight = "bold", size = 20)

# Displaying heatmap
plt.show()
# Out:
# <ipython-input-83-5c46f6bf3e5d>:7: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   ax = sns.heatmap(hotel_df.corr(), cmap = "YlGnBu", annot = True)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * A **correlation heatmap** is used to display the **correlation between multiple variables** as a color-coded matrix. It allows us to identify how well different variables correlate with each other as well as whether that correlation is positive or negative.
#
# * In a correlation heatmap, each variable is represented by a row and column, and the cells show the correlation between them. The color of each cell represents the strength and direction of the correlation, with darker the colour stronger the correlation.
#
# * Here we have used correlation heatmap to know the correlation between all the variables present in the dataset with their correlation coeficients (positive or negative).

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * From the above heatmap, we observe some strong & weak correlation between a few variables. Let's see few in detail:
#
#   * The variable '**is_canceled**' has a small **postive correlation** with '**adr**'. That means booking cancellation does not affect average daily rate (ADR) to a large extent.
#
#   * Similarly, the variable '**is_canceled**' has a slight **postive correlation** with '**previous_cancellations**'. That means guest who had a record of booking cancellation in past have higher possibilty of cancelling a booking again.
#
#   * The variables '**lead_time**' and '**is_canceled**' have small **positive correlation**. The means higher the lead time more the chances of booking cancellation.
#
#   * The variables '**total_members**' and '**adr**' has a strong **positive correalation**. That means more member per booking can add on to more ADR.
#
#   * The variables '**is_repeated_guest**' and '**previous_bookings_not_canceled**' have good **positive correlation**. That means guest who visit often generally don't have history for past booking cancellations.
#
#   * The variable '**total_members**' has a high **postive correlation** with '**adults**' and '**children**'. That means most of the guest that visit hotels are adults and childrens (single, couple or family).
#
# Rest all correlations can be depicted from the above chart systematically.

# %% [markdown]
# #### **Chart-2**: Pair Plot

# %%
# Pair Plot visualization code

# Creating a new data set as the original data set is taking long time to execute
# We have added columns in 'hotel_df_columns' from the original data set 'hotel_df'
hotel_df_columns = pd.DataFrame(hotel_df.loc[:, ['hotel','is_canceled', 'lead_time', 'arrival_date_year', 'arrival_date_month', 'meal', 'market_segment', 'distribution_channel', 'deposit_type', 'days_in_waiting_list', 'customer_type', 'adr', 'total_nights', 'total_members', 'reserved_room_assigned', 'guest_category']])

# Create a pairplot with hue hotel
ax = sns.pairplot(hotel_df_columns, hue = 'hotel')

# Display Plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * **Pairplot** allows us to **plot pairwise relationships between different variables** within a dataset. This creates a nice visualisation and helps us understand the data by summarising a large amount of data in a single figure. It is essential when we are exploring our dataset and trying to become familiar with it.
#
# * Pairplots are a powerful tool to quickly **explore distributions and relationships** in a dataset. They provide us with a comprehensive first look at our data and is important in data analysis projects.
#
# * Here, we have used pairplot to **analyse the pattern and relationship between different variables**. It's similar to the correlation heatmap with slight difference of representing it in graphical form.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * From above what we can see is that longer lead time does not result in cancellations. ['**lead_time**' v/s '**is_canceled**'].
#
# * Here we can see a rise in advance bookings year after year (2015, 2016 & 2017). ['**lead_time**' v/s '**arrival_date_year**']
#
# * As per the graph, '**arrival_date_year**' and '**days_in_waiting_list**' for year 2016 has the longest waiting period for bookings.
#
# * As per findings from the graph, more the waiting period of booking less the ADR / cost. ['**adr**' v/s '**days_in_waiting_list**']
#
# * From above the graph of '**is_canceled**' & '**days_in_waiting_list**', we can conclude that waiting period for bookings is not a reason for booking cancellation.
#
# * From the above graph of '**adr**' & '**total_members**', most of the guest that visit hotels are either single or couple and ADR is higher in their case.
#
# * Lastly, most of the visits, bookings and reservations belong to **city hotel** and overall ADR is higher in case of city hotel than resort hotel.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# The hotel industry is ever-evolving and for them to stay profitable, they must **adopt new business strategies**. However, the industry is transforming every year, making it difficult for hotel businesses to maintain the high standards.
#
# Talking about the current scenario of the hotel industry, it is much better than what it was during covid-19 pandemic years. The industry is seeing a moderate growth and has great potential to grow even more in the future. However, there are certain changes in traveler's behaviors and preferences.
#
# > Let's see how **EDA** on '**Hotel Booking Dataset**' can help hotel industry to build better business strategies:
#   * Identify your **audience** first.
#   * Work on improving **brand recognition**.
#   * Create mobile-friendly **marketing** by giving ads online and offers to customers.
#   * Use **data** to develop informed hotel strategies and decisions.
#   * Work with various **distribution channels** by analyzing cost vs profit to generate more bookings.
#   * Start monitoring **customer behavior and preferences** to generate demand.
#   * Conduct **competitor analysis** inorder to understand the hotel's position in market.
#   * Incorporate **revenue management** on every strata of hotel administration.
#   * Optimise hotel's **direct booking channel**.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# > Let's conclude the project by describing all the data visualizations undertaken alnong with their brief insights:
#   * ***Univariate Analysis***:
#     1. Which country has the highest and lowest no. of bookings?
#       * **Portugal** (**PRT**) and **Netherlands** (**NLD**).
#     2.  Which country has most and least no. of guests?
#       * **Portugal** (**PRT**) and **United States of America** (**USA**).
#     3. Which agent has most and least no. of bookings?
#       * **Agent no. 9** (34%) and **Agent no. 1** (1.5%).
#     4. Which type of hotel has more bookings?
#       * **City hotel** (61%) and Resort hotel (39%).
#     5. Which is the most preferable mode of booking by customers?
#       * **Online TA** [Online Travel Agents] (59%).
#     6. What are the total no. of bookings done year-wise & month-wise?
#       * **Year-wise**: 2015 -> 15%, 2016 -> 48.5%, 2017 -> 36%.
#       * **Month-wise**: July (11.5%) and August (13%) with highest bookings. And lowest is January, November & December with 5% each.
#     7. Which meal is ordered the most and least?
#       * **BB** (Bed & Breakfast) -> 78% and **FB** (Full-Board) -> 0.5%.
#     8. Which type of customer is often and least found in hotels?
#       * **Transient** -> 82% and **Group** -> 0.5%.
#     9. How many confirmed bookings are there per month? and What is the total count for cancelled bookings?
#       * **Confirmed booking** is highest for months July & August. And lowest for January, November & December.
#       * **Cancelled booking** count -> 28% and **Not Cancelled booking** count -> 72%.
#     10. Which deposit type is most and least popular in hospitality industry?
#       * **No Deposit** -> 98.5%, **Non Refund** -> 1.1%, and **Refundable** -> 0.1%.
#     11. How many customers opt for car parking space?
#       * **Yes** -> 91% and **No** -> 9%.
#     12. Which room type is most and least reserved by customers?
#       * **Room A** -> 65% and **Room L** -> 0.01%.
#     13. Which room type is most and least assigned to customers?
#       * **Room A** -> 53% and **Room k** -> 0.2%. Room L -> 0%.
#     14. What is the percent(%) count of Repeated Guest?
#       * **No** -> 96% and **Yes** -> 4%.
#     15. What is the percent(%) count for highest and lowest members per room?
#       * **2 guests per room** -> 65% and **5 guests per room** -> 0.1%.
#     16. How many guest show-up for their reservation?
#       * **72% of guest who made reservations show-up**.
#   * ***Bivariate Analysis***:
#     1. What is the cancelation rate for each type of hotel?
#       * **City hotel cancelation rate** -> 18% and **Resort hotel cancelation rate** -> 9%.
#     2. What is the Average Daily Rate (ADR) for each hotel (Resort & City) (Month-wise & Year-wise)?
#       * **Year-wise ADR**: City and Resort hotel -> 2017 has highest ADR and least ADR for Resort hotel in year 2016 & City hotel in year 2015.
#       *  **Month-wise ADR**: Resort hotel -> Highest - July & August and Lowest - November & January and City hotel -> Highest - May, June, July, & August and Lowest - November & January.
#     3. Is high lead_time responsible for booking cancellations? and Is reserved room not assigned a reason for booking cancellations?
#       * **No, high lead time is not the reason for booking cancellation**.
#       * **No, reserved room not assigned is not the reason for booking cancellation**.
#     4. Which guest category (single, couple & family) has how many reservations?
#       * **City hotel**: single -> 12%, couple -> 39%, & family -> 11%.
#       * **Resort hotel**: single -> 7%, couple -> 27%, & family -> 5%.
#     5. Which distribution channels and market segments has the most and least no. of cancellations?
#       * **Distribution channel**: Highest -> TA/TO (Travel Agents/Tour Operators) - 25% and Lowest -> GDS (Global Distribution Systems) - 0.04%.
#       * **Market segment**: Highest -> Online TA (Online Travel Agents) - 21% and Lowest -> Aviation - 0.05%.
#   * ***Multivariate Analysis***
#     1. **Correlation Heatmap** -> where one can see correlation between all the variables with the help of correlation coefficient.
#     2. **Pair Plot** -> where one can analyse the pattern and relationship between different variables.
#
#
# *When it comes to the growth and success of a hotel business, smart decisions are important. Because these decisions empower hotel owners and managers to **optimize hotel revenue, enhance the guest experience, analyze their competitors, and create better marketing strategies** to maximize ROI. Therefore, use of proper hotel related data and insights is crucial to gain higher profits and make informed decisions.*

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
